# %% [markdown]
# # ARIMA algorithm with the `Darts` library

# %% [markdown]
# Imports

# %%
from darts import models
from darts.utils.timeseries_generation import datetime_attribute_timeseries

# %% [markdown]
# Training Data

# %%
from darts.datasets import AirPassengersDataset

series = AirPassengersDataset().load()

# %% [markdown]
# Model Instance

# %%
future_cov = datetime_attribute_timeseries(series, "month", cyclic=True, add_length=6)
model = models.ARIMA(p=12, d=1, q=2)

# %% [markdown]
# Fit the Model

# %%
model.fit(series, future_covariates=future_cov)
# Out:
# c:\Users\xiach\anaconda3\envs\model\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\xiach\anaconda3\envs\model\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(p=12, d=1, q=2, seasonal_order=(0, 0, 0, 0), trend=None, random_state=None, add_encoders=None)

# %% [markdown]
# Prediction

# %%
pred = model.predict(6, future_covariates=future_cov)

pred
# Out:
# <TimeSeries (Month: 6, component: 1, sample: 1)> Size: 48B
# array([[[451.36509777]],
#
#        [[416.89049052]],
#
#        [[443.10527496]],
#
#        [[481.07922405]],
#
#        [[502.11315521]],
#
#        [[555.50181293]]])
# Coordinates:
#   * Month      (Month) datetime64[ns] 48B 1961-01-01 1961-02-01 ... 1961-06-01
#   * component  (component) object 8B '#Passengers'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None
#     metadata:           None
